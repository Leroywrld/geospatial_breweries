# %%
import pandas as pd
import numpy as np
#call our dataset as data
data=pd.read_csv("C:\\Users\\USER\\Downloads\\open_breweries_US.csv")

# %%
#Getting general information about the dataset
data.head()
# Out:
#    Unnamed: 0                                    id                  name  \
# 0           0  5128df48-79fc-4f0f-8b52-d06be54d0cec      (405) Brewing Co
# 1           1  9c5a66c8-cc13-416f-a5d9-0a769c87d318      (512) Brewing Co
# 2           2  ef970757-fe42-416f-931d-722451f1f59c  10 Barrel Brewing Co
# 3           3  6d14b220-8926-4521-8d19-b98a2d6ec3db  10 Barrel Brewing Co
# 4           4  e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2  10 Barrel Brewing Co
#
#   brewery_type                    address_1 address_2  address_3       city  \
# 0        micro               1716 Topeka St       NaN        NaN     Norman
# 1        micro        407 Radam Ln Ste F200       NaN        NaN     Austin
# 2        large                    1501 E St       NaN        NaN  San Diego
# 3        large                62970 18th St       NaN        NaN       Bend
# 4        large  1135 NW Galveston Ave Ste B       NaN        NaN       Bend
#
# ...

# %% [markdown]
# Clearly,the dataset has some missing values,

# %%
data.describe()
# Out:
#         Unnamed: 0  address_3    longitude     latitude         phone
# count  6125.000000        0.0  4508.000000  4508.000000  5.537000e+03
# mean   3062.000000        NaN   -97.579241    39.869357  8.719509e+09
# std    1768.279531        NaN    23.541375     6.332873  3.266579e+10
# min       0.000000        NaN  -149.895820    26.048002  1.825722e+09
# 25%    1531.000000        NaN  -118.832267    36.693623  4.065472e+09
# 50%    3062.000000        NaN   -94.415837    39.449933  5.415851e+09
# 75%    4593.000000        NaN   -82.630713    43.063800  7.274956e+09
# max    6124.000000        NaN    -0.000860    63.864759  3.535990e+11

# %%
#Finding the number of columns and rows in this dataset
no_of_rows=data.shape[0]
no_of_columns=data.shape[1]
print(no_of_rows)
print(no_of_columns)
# Out:
# 6125
# 17

# %% [markdown]
# This dataset has 6125 rows and 17 columns.

# %%
#DATA CLEANING
#Checking the columns that have missing values using the .isnull() function
missing_values=data.isnull().sum()
missing_values[0:17]
# Out:
# Unnamed: 0           0
# id                   0
# name                 0
# brewery_type         0
# address_1          392
# address_2         6076
# address_3         6125
# city                 0
# state_province       0
# postal_code          0
# country              0
# longitude         1617
# latitude          1617
# phone              588
# website_url       1127
# state                0
# street             392
# dtype: int64

# %% [markdown]
# Some columns have missing values ,some don't.

# %%
#Dropping missing values
